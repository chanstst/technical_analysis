# %% [markdown]
# # Stocks on Watch

# %% [markdown]
# ### Import libaries and data files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
from datetime import date, timedelta
from math import ceil

# %%
import sys
sys.path.insert(0, '../common')
from myfunctions import *

# %%
root = "../"

# %% [markdown]
# # Load an array of stocks

# %%
codes = pd.read_csv(root + "data/on_watch.csv")["code"].to_list()
codes
# Out:
# ['0981.HK',
#  '2318.HK',
#  '0857.HK',
#  '0941.HK',
#  '0939.HK',
#  '1299.HK',
#  '1378.HK',
#  '2600.HK',
#  '0992.HK',
#  '1308.HK',
#  '0144.HK',
#  '0868.HK',
#  '0347.HK',
#  '0322.HK',
#  '6878.HK',
#  '2399.HK',
#  '3306.HK',
#  '0460.HK',
#  '0027.HK',
#  '1171.HK',
#  '2343.HK',
#  '0220.HK',
#  '1055.HK',
#  '9939.HK',
#  '1093.HK',
#  '2020.HK',
#  '3899.HK',
#  '0769.HK',
#  '0754.HK',
#  '6978.HK']

# %%
charts_list(codes)
