# %% [markdown]
# # Stocks on Watch

# %% [markdown]
# ### Import libaries and data files

# %%
import pandas as pd

# %%
import sys
sys.path.insert(0, '../common')
from myfunctions_selected import *

# %%
root = "../"

# %% [markdown]
# ### Multi-chart display

# %%
file_tickers = root + "user_input/selected_stocks.csv"

# %%
data = pd.read_csv(file_tickers, index_col=None, header=None, names=["tickers"], engine="python")
codes = data["tickers"].to_list()

# %%
codes
# Out:
# ['NIO',
#  '0002.HK',
#  '0003.HK',
#  '0004.HK',
#  '0005.HK',
#  '0006.HK',
#  '0008.HK',
#  '0010.HK',
#  '0011.HK',
#  '0012.HK']

# %%
charts_list(codes)
